# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lower, trim

spark  = SparkSession.builder.getOrCreate()

# %%
data = [
    {"user_id": 1, "email": " Alice@Email.com "},
    {"user_id": 2, "email": "BOB@EMAIL.COM"},
]

df = spark.createDataFrame(data)

# %%
clean_df = (
    df.filter(col("user_id")
    .isNotNull())
    .filter(col("email").isNotNull())
    .select(col("user_id"),lower(trim(col("email"))).alias("email"))
                                                                                 
)

# %%
clean_df.show()
# Out:
# +-------+---------------+
# |user_id|          email|
# +-------+---------------+
# |      1|alice@email.com|
# |      2|  bob@email.com|
# +-------+---------------+

# %%
clean_df.printSchema()
# Out:
# root
#  |-- user_id: long (nullable = true)
#  |-- email: string (nullable = true)
